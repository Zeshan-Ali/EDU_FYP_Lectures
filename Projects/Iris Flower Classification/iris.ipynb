# %% [markdown]
# <h1><center> Iris Flower Classification </center></h1>
# <hr>

# %% [markdown]
#  <h1>Objective</h1>
#  <p>The aim is to classify iris flowers among three species from measurements of sepals and petals' length and width.The iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.The central goal here is to design a model that makes useful classifications for new flowers or, in other words, one which exhibits good generalization.</p>
#  <hr>

# %% [markdown]
# **Importing libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as  plt
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report

# %% [markdown]
# **Importing Data from .csv file**

# %%
columns=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"]
dataset = pd.read_csv('iris_data.csv',names=columns)
dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
dataset.shape
# Out:
# (150, 5)

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# <hr>

# %% [markdown]
# **Histogram of petal length**

# %%
sns.FacetGrid(dataset,hue="Species",height=5) \
    .map(sns.distplot,"PetalLengthCm") \
    .add_legend()
plt.show()
# Out:
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Histogram of petal width**

# %%
sns.FacetGrid(dataset,hue="Species",height=8) \
    .map(sns.distplot,"PetalWidthCm") \
    .add_legend()
plt.show()
# Out:
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Histogram of sepal length**

# %%
sns.FacetGrid(dataset,hue="Species",height=8) \
    .map(sns.distplot,"SepalLengthCm") \
    .add_legend()
plt.show()
# Out:
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Histogram of sepal width**

# %%
sns.FacetGrid(dataset,hue="Species",height=5) \
    .map(sns.displot,"SepalWidthCm") \
    .add_legend()
plt.show()
# Out:
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **2D scatter plot**

# %%
dataset.plot(kind='scatter', x='SepalLengthCm',y='SepalWidthCm')
plt.show()

# %% [markdown]
# **2D scatter plot with color-coding for each flower type/class.**

# %%
sns.set_style("whitegrid")
sns.FacetGrid(dataset, hue="Species", height=4) \
    .map(plt.scatter,"SepalLengthCm","SepalWidthCm") \
    .add_legend()
plt.show()
# Out:
# C:\Users\zish0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Pairwise Scatter Plot**

# %%
sns.set_style("whitegrid")
sns.pairplot(dataset,hue="Species",size=3,aspect=1)
plt.show()
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Data Preprocessing
# <hr>

# %%
dataset["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
dataset.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %% [markdown]
# **descriptive statistics of data set**

# %%
dataset.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **Checking for Null Values**

# %%
dataset.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
dataset['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# **label Encoding**

# %%
label_encoder = preprocessing.LabelEncoder() 
dataset['Species']= label_encoder.fit_transform(dataset['Species']) 

dataset['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
X = dataset.drop(["Species"], axis=1)
y = dataset["Species"]

# %% [markdown]
# **Splitting the dataSet**

# %%
#X = dataset.iloc[:, [2,3]].values

#y = dataset.iloc[:, 4].values

# %%
len(X)
# Out:
# 150

# %%
len(y)
# Out:
# 150

# %% [markdown]
# **heatmap is to identify the highly correlated features**

# %%
plt.figure(figsize=(7,4)) 
sns.heatmap(dataset.corr(),annot=True,cmap='cubehelix_r')
plt.show()

# %% [markdown]
# # Model Development
# <hr>

# %% [markdown]
# **splitting the dataset into train set and test set**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state = 2)

# %% [markdown]
# **Feature Scaling**

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.fit_transform(X_test)

# %% [markdown]
# ##  DecisionTree Classifier

# %%
X_test
# Out:
# array([[-1.36325324,  0.85909557, -1.25317194, -1.10347207],
#        [-1.36325324,  0.1296748 , -1.19603644, -1.23380342],
#        [-0.04783345, -1.32916673,  0.80370601,  1.11216083],
#        [-1.124086  , -0.11346545, -1.25317194, -1.36413476],
#        [-1.124086  ,  0.85909557, -0.96749444, -1.23380342],
#        [ 1.74592081, -0.11346545,  1.26079   ,  0.59083544],
#        [-0.88491877, -0.11346545, -1.13890094, -1.23380342],
#        [ 1.14800273, -1.32916673,  1.26079   ,  0.85149813],
#        [ 0.78925187, -0.59974596,  1.14651901,  1.24249217],
#        [-1.124086  , -0.11346545, -1.25317194, -1.10347207],
#        [-0.52616792,  1.58851633, -1.19603644, -1.23380342],
#        [-1.60242047,  0.37281506, -1.31030744, -1.23380342],
#        [-0.88491877,  0.37281506, -1.36744293, -1.23380342],
#        [-0.4065843 ,  2.07479684, -1.08176544, -0.97314072],
#        [ 0.3109174 ,  0.85909557,  0.51802852,  0.59083544],
#        [ 0.90883549, -0.59974596,  0.57516402,  0.46050409],
#        [-1.48283685, -1.81544723, -1.31030744, -1.10347207],
#        [-0.04783345, -0.35660571,  0.34662203,  0.1998414 ],
#        [ 1.14800273,  0.61595531,  1.20365451,  1.76381756],
#        [-0.28700068, -1.32916673,  0.23235103,  0.1998414 ],
#        [ 1.14800273, -0.11346545,  0.80370601,  0.72116679],
#        [ 0.78925187, -0.35660571,  0.40375752,  0.1998414 ],
#        [ 0.78925187,  0.37281506,  0.97511251,  1.50315487],
#        [-0.16741706, -0.84288622,  0.34662203,  0.1998414 ],
#        [ 0.66966826, -1.81544723,  0.46089302,  0.1998414 ],
#        [-1.24366962,  0.37281506, -1.13890094, -1.23380342],
#        [-1.24366962,  0.37281506, -1.31030744, -1.23380342],
#        [ 0.43050102, -0.11346545,  0.74657052,  0.85149813],
#        [-0.76533515,  1.83165658, -0.96749444, -0.97314072],
#        [ 1.74592081,  0.37281506,  1.375061  ,  0.85149813],
#        [ 0.55008464, -0.59974596,  0.68943502,  0.85149813],
#        [-0.76533515,  0.61595531, -1.08176544, -0.84280938],
#        [-0.16741706, -0.35660571,  0.00380903,  0.1998414 ],
#        [ 2.3438389 ,  1.83165658,  1.77500949,  1.37282352],
#        [-0.4065843 , -0.11346545,  0.51802852,  0.46050409],
#        [ 0.07175017,  2.31793709, -1.36744293, -1.23380342],
#        [ 0.78925187, -0.59974596,  1.14651901,  1.37282352],
#        [ 0.43050102, -0.11346545,  0.57516402,  0.33017275],
#        [-0.28700068, -1.81544723,  0.23235103,  0.1998414 ],
#        [ 1.38716996,  0.1296748 ,  0.86084151,  1.50315487],
#        [ 0.3109174 , -0.35660571,  0.51802852,  0.46050409],
#        [ 0.55008464, -0.35660571,  0.40375752,  0.1998414 ],
#        [ 1.26758634,  0.37281506,  1.3179255 ,  1.50315487],
#        [-0.88491877, -1.81544723, -0.16759746, -0.19115264],
#        [-1.124086  ,  0.85909557, -1.13890094, -1.23380342]])

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Predicting the test results**

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 2, 0, 0, 2, 0, 2, 2, 0, 0, 0, 0, 0, 1, 1, 0, 1, 2, 1, 2, 1,
#        2, 1, 1, 0, 0, 2, 0, 2, 2, 0, 1, 2, 1, 0, 2, 1, 1, 2, 1, 1, 2, 1,
#        0])

# %% [markdown]
# **Making the confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[17,  0,  0],
#        [ 0, 14,  1],
#        [ 0,  0, 13]], dtype=int64)

# %% [markdown]
# ### Visualization

# %% [markdown]
# **Visualising the Training set results**

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('pink','skyblue','gray')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('pink', 'skyblue','gray'))(i), label = j)
plt.title('Decision tree Classifier (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 5
#       2 X_set, y_set = X_train, y_train
#       3 X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#       4                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
# ----> 5 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#       6              alpha = 0.75, cmap = ListedColormap(('pink','skyblue','gray')))
#       7 plt.xlim(X1.min(), X1.max())
#       8 plt.ylim(X2.min(), X2.max())
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
#     528 check_is_fitted(self)
# --> 529 X = self._validate_X_predict(X, check_input)
#     530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     force_all_finite = True
# --> 489 X = self._validate_data(
#     490     X,
#     491     dtype=DTYPE,
#     492     accept_sparse="csr",
#     493     reset=False,
#     494     force_all_finite=force_all_finite,
#     495 )
#     496 if issparse(X) and (
#     497     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     498 ):
#     499     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 2 features, but DecisionTreeClassifier is expecting 4 features as input.

# %% [markdown]
# **Visualising the Test set results**

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green','blue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green','blue'))(i), label = j)
plt.title('Decision tree Classifier  (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# **Accuracy**

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
print('The accuracy of the Decision Tree Classifier is : %.2f'%accuracy_score(y_pred,y_test))
rmse = sqrt(mean_squared_error(y_test, y_pred))
print("RMSE value = %.2f"%rmse)
print("R2 Score= %.2f"%r2_score(y_test, y_pred))
# Out:
# The accuracy of the Decision Tree Classifier is : 0.98
# RMSE value = 0.15
# R2 Score= 0.97

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        17\n           1       1.00      0.93      0.97        15\n           2       0.93      1.00      0.96        13\n\n    accuracy                           0.98        45\n   macro avg       0.98      0.98      0.98        45\nweighted avg       0.98      0.98      0.98        45\n'

# %% [markdown]
# ## KNN Algorithm

# %%
from sklearn import neighbors
model = neighbors.KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
predict = model.predict(X_test)

# %% [markdown]
# **Accuracy**

# %%
#for checking the model accuracy
print('The accuracy of the KNN is',accuracy_score(predict,y_test))
rmse = sqrt(mean_squared_error(y_test, predict))
print("RMSE value = %.2f"%rmse)
print("R2 Score= %.2f"%r2_score(y_test, predict))
# Out:
# The accuracy of the KNN is 0.9555555555555556
# RMSE value = 0.21
# R2 Score= 0.93

# %% [markdown]
# ## SVM

# %%
from sklearn import svm
svc = svm.SVC(C=1.0, kernel='rbf')

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred = svc.predict(X_test)

# %% [markdown]
# **validation**

# %%
print('The accuracy of the SVM is: %.2f'%accuracy_score(pred,y_test))
rmse = sqrt(mean_squared_error(y_test, pred))
print("RMSE value = %.2f"%rmse)
print("R2 Score= %.2f"%r2_score(y_test, pred))
# Out:
# The accuracy of the SVM is: 0.98
# RMSE value = 0.15
# R2 Score= 0.97

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression # for Logistic Regression algorithm
model = LogisticRegression()
model.fit(X_train,y_train) 
prediction=model.predict(X_test)

# %% [markdown]
# **Accuracy**

# %%
print('The accuracy of the Logistic Regression using Petals is:',accuracy_score(prediction,y_test))
rmse = sqrt(mean_squared_error(y_test, prediction))
print("RMSE value = %.2f"%rmse)
print("R2 Score= %.2f"%r2_score(y_test, prediction))
# Out:
# The accuracy of the Logistic Regression using Petals is: 0.9777777777777777
# RMSE value = 0.15
# R2 Score= 0.97

# %% [markdown]
# # naive_bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train,y_train) 
predicted= model.predict(X_test)

# %% [markdown]
# **Accuracy**

# %%
print('The accuracy of the naive_bayes is:',accuracy_score(predicted,y_test))
rmse = sqrt(mean_squared_error(y_test, predicted))
print("RMSE value = %.2f"%rmse)
print("R2 Score= %.2f"%r2_score(y_test, predicted))
# Out:
# The accuracy of the naive_bayes is: 0.9777777777777777
# RMSE value = 0.15
# R2 Score= 0.97

# %% [markdown]
# **Work by Sarvesh Sharma**
